# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
np.random.seed(1)
df = pd.DataFrame({
    'x1': np.random.normal(0, 2, 10000),
    'x2': np.random.normal(5, 3, 10000),
    'x3': np.random.normal(-5, 5, 10000)
})

scaler = preprocessing.StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns = ['x1', 'x2', 'x3'])

fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (6,5))
ax1.set_title('Before Scaling')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)
ax2.set_title('After Standard Scaler')
sns.kdeplot(scaled_df['x1'], ax=ax2)
sns.kdeplot(scaled_df['x2'], ax=ax2)
sns.kdeplot(scaled_df['x3'], ax=ax2)
plt.show()

# %%
df
# Out:
#             x1         x2         x3
# 0     3.248691   4.632578 -14.657819
# 1    -1.223513   5.684509  -5.802131
# 2    -1.056344   3.943085  -9.161098
# 3    -2.145937   2.508340  -6.030558
# 4     1.730815   4.216731   0.131275
# ...        ...        ...        ...
# 9995  0.145917   2.170375  -1.550878
# 9996  0.978204   7.346647  -2.235902
# 9997 -2.028288  12.225301  -5.419191
# 9998 -0.125392   7.648357 -11.417673
# 9999 -2.875740   4.701211  -3.288438
#
# [10000 rows x 3 columns]

# %%
scaled_df
# Out:
#             x1        x2        x3
# 0     1.616535 -0.131753 -1.924757
# 1    -0.622285  0.218475 -0.146416
# 2    -0.538598 -0.361311 -0.820942
# 3    -1.084057 -0.838991 -0.192287
# 4     0.856675 -0.270204  1.045092
# ...        ...       ...       ...
# 9995  0.063263 -0.951512  0.707293
# 9996  0.479912  0.771862  0.569731
# 9997 -1.025161  2.396149 -0.069516
# 9998 -0.072557  0.872313 -1.274092
# 9999 -1.449402 -0.108902  0.358368
#
# [10000 rows x 3 columns]

# %%
fig, ax = plt.subplots()
ax.hist(np.random.normal(loc = 50, scale = 5, size = 1000))
# Out:
# (array([  5.,   4.,  20.,  82., 197., 252., 230., 147.,  48.,  15.]),
#  array([30.2842884 , 33.72510276, 37.16591712, 40.60673148, 44.04754585,
#         47.48836021, 50.92917457, 54.36998893, 57.81080329, 61.25161765,
#         64.69243201]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.DataFrame({
    # positive skew
    'x1': np.random.chisquare(8, 1000),
    # negative skew 
    'x2': np.random.beta(8, 2, 1000) * 40,
    # no skew
    'x3': np.random.normal(50, 3, 1000)
})

scaler = preprocessing.MinMaxScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=['x1', 'x2', 'x3'])

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(6, 5))
ax1.set_title('Before Scaling')
sns.kdeplot(df['x1'], ax=ax1)
sns.kdeplot(df['x2'], ax=ax1)
sns.kdeplot(df['x3'], ax=ax1)
ax2.set_title('After Min-Max Scaling')
sns.kdeplot(scaled_df['x1'], ax=ax2)
sns.kdeplot(scaled_df['x2'], ax=ax2)
sns.kdeplot(scaled_df['x3'], ax=ax2)
plt.show()

# %%
df
# Out:
#             x1         x2         x3
# 0     8.913396  33.282653  54.509849
# 1     5.583017  38.986294  52.473472
# 2    19.713205  26.377055  48.803613
# 3    23.293714  31.520740  50.593609
# 4    11.508381  38.646724  49.702286
# ..         ...        ...        ...
# 995   5.970794  34.391166  53.369197
# 996   8.611427  35.227850  49.953444
# 997  13.534576  34.324809  58.301257
# 998   8.513871  36.818726  49.019199
# 999   5.823893  39.207967  47.490093
#
# [1000 rows x 3 columns]

# %%
scaled_df
# Out:
#            x1        x2        x3
# 0    0.320592  0.776009  0.748636
# 1    0.184702  0.971903  0.645125
# 2    0.761260  0.538834  0.458583
# 3    0.907357  0.715496  0.549570
# 4    0.426476  0.960240  0.504263
# ..        ...       ...       ...
# 995  0.200524  0.814082  0.690656
# 996  0.308271  0.842818  0.517030
# 997  0.509152  0.811802  0.941357
# 998  0.304290  0.897457  0.469541
# 999  0.194530  0.979517  0.391815
#
# [1000 rows x 3 columns]
